# %%
import pandas as pd

# 创建步骤数据表
steps_data = [
    {
        "order": "S6",
        "components": "Hex cap screw (big),C26",
        "tool": None,
        "instructions": "Thread the big hex cap screw (C26) by hand into the threaded hole above the support (C1).",
        "time": 10
    },
    {
        "order": "S9",
        "components": "Drive shaft companion flange,C8",
        "tool": "Allen key,T5",
        "instructions": "Attach the drive shaft companion flange (C8) onto the shaft (C5), ensuring alignment of the front surfaces of both the shaft (C5) and the flange (C8). Secure it in place using the Allen key (T5) with half a turn.",
        "time": 45
    },
    {
        "order": "S12",
        "components": "Pump housing,C2;Washers,C17;Nuts,C18",
        "tool": "Wrench size 13,T6",
        "instructions": "Mount the pump housing (C2) on the shaft (C5) so that the 4 short stud bolts (C23) fit into the 4 holes on the support (C1). Mount the 4 washers (C17) and 4 nuts (C18) on the 4 short stud bolts (C23). Start threading the nuts (C18) by hand and then gradually tighten the nuts (C18) using the wrench size 13 (T6) in a crisscross pattern to ensure even pressure distribution.",
        "time": 60
    }
]

# 创建组件和工具数据表
components_tools_data = [
    {"name": "Hex cap screw (big)", "id": "C26"},
    {"name": "Drive shaft companion flange", "id": "C8"},
    {"name": "Pump housing", "id": "C2"},
    {"name": "Washers", "id": "C17"},
    {"name": "Nuts", "id": "C18"},
    {"name": "Allen key", "id": "T5"},
    {"name": "Wrench size 13", "id": "T6"}
]

# 将数据转换为DataFrame
steps_df = pd.DataFrame(steps_data)
components_tools_df = pd.DataFrame(components_tools_data)

# 写入Excel文件
with pd.ExcelWriter('steps_components_tools.xlsx') as writer:
    steps_df.to_excel(writer, sheet_name='Steps', index=False)
    components_tools_df.to_excel(writer, sheet_name='Components_Tools', index=False)
